# %%
import pandas as pd
df = pd.read_csv("clean_reviews.csv")
df.head()
# Out:
#                                               review sentiment  \
# 0  The desk lamp broke after TWO days. Total wast...  negative
# 1  The headphones exceeded my expectations, reall...  positive
# 2  I regret buying this headphones. Cheap materia...  negative
# 3  The blender broke after TWO days. Total waste ...  negative
# 4  The blender exceeded my expectations, really w...  positive
#
#                                           clean_text
# 0          desk lamp broke two day total waste money
# 1    headphone exceeded expectation really well made
# 2  regret buying headphone cheap material terribl...
# 3            blender broke two day total waste money
# 4      blender exceeded expectation really well made

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test, y_train, y_test = train_test_split(df["clean_text"], df["sentiment"], test_size=0.2, random_state=42, stratify=df["sentiment"])

#COUNT VECTORIZER

bow = CountVectorizer()
X_train_bow = bow.fit_transform(X_train)
X_test_bow = bow.transform(X_test)

print(X_train_bow.shape)
print(X_test_bow.shape)
print(bow.get_feature_names_out()[:20])
print()
#TF-IDF
vectorizer = TfidfVectorizer()

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)
print()
print(X_train_tfidf.shape)
print(X_test_tfidf.shape)
print(vectorizer.get_feature_names_out()[:20])
# Out:
# (120, 60)
# (30, 60)
# ['1010' 'absolutely' 'amazing' 'arrived' 'backpack' 'best' 'blender'
#  'bottle' 'bought' 'broke' 'buying' 'case' 'cheap' 'customer' 'damaged'
#  'day' 'delivery' 'desk' 'disappointed' 'ever']
#
#
# (120, 60)
# (30, 60)
# ['1010' 'absolutely' 'amazing' 'arrived' 'backpack' 'best' 'blender'
#  'bottle' 'bought' 'broke' 'buying' 'case' 'cheap' 'customer' 'damaged'
#  'day' 'delivery' 'desk' 'disappointed' 'ever']
